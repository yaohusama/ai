# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt
img=cv2.imread('dujuan_1.png',0)
ret,thresh1=cv2.threshold(img,127,255,cv2.THRESH_BINARY)
#cv2.imshow('red part only',thresh1)
plt.imshow(thresh1,'gray')#不能用cv2

# %%
img0=plt.imread('dujuan_1.png',1)
print(img0.shape)#彩色图像
# Out:
# (761, 741, 3)

# %%
r,g,b=cv2.split(img0)
print(r,g,b)
# Out:
# [[0.94509804 0.9098039  0.9098039  ... 0.9529412  0.94509804 0.8       ]
#  [0.9490196  0.9137255  0.9137255  ... 0.95686275 0.9490196  0.8039216 ]
#  [0.9490196  0.9137255  0.9137255  ... 0.95686275 0.9490196  0.8039216 ]
#  ...
#  [0.         0.         0.         ... 0.         0.01176471 0.16862746]
#  [0.         0.         0.         ... 0.         0.01176471 0.16862746]
#  [0.00392157 0.00392157 0.00392157 ... 0.00392157 0.01568628 0.17254902]] [[0.39607844 0.00392157 0.00392157 ... 0.00392157 0.01568628 0.17254902]
#  [0.39215687 0.         0.         ... 0.         0.01176471 0.16862746]
#  [0.39215687 0.         0.         ... 0.         0.01176471 0.16862746]
#  ...
#  [0.         0.         0.         ... 0.         0.01176471 0.16862746]
#  [0.         0.         0.         ... 0.         0.01176471 0.16862746]
#  [0.00392157 0.00392157 0.00392157 ... 0.00392157 0.01568628 0.17254902]] [[0.39607844 0.00392157 0.00392157 ... 0.00392157 0.01568628 0.17254902]
# ...

# %%
plt.imshow(img0)

# %%
img0[:,:,1]=0
plt.imshow(img0)

# %%
img0=cv2.imread('dujuan_1.png')
print(img0.shape)
# Out:
# (761, 741, 3)

# %%
b,g,r=cv2.split(img0)
img0=cv2.merge([r,g,b])
#plt.imshow(img0)
cv2.imshow('1',img0)
cv2.waitKey()
cv2.destroyAllWindows()
img1=cv2.cvtColor(img0,cv2.COLOR_BGR2HSV)
lower_red=np.array([100,43,46])
upper_red=np.array([124,255,255])
mask=cv2.inRange(img1,lower_red,upper_red)
res=cv2.bitwise_and(img0,img0,mask=mask)
b,g,r=cv2.split(res)
res=cv2.merge([r,g,b])
cv2.imshow('red',res)
cv2.waitKey()
cv2.destroyAllWindows()
# plt.imshow(img0)

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import colors
frame = cv2.imread("dujuan_1.jpg")
# BGR空间转换到HSV颜色空间
hsv = cv2.cvtColor(frame, cv2.COLOR_BGR2HSV)
# 分割通道
h, s, v = cv2.split(hsv)
fig = plt.figure()
axis = fig.add_subplot(1, 1, 1, projection="3d")

pixel_colors = frame.reshape((np.shape(hsv)[0]*np.shape(hsv)[1], 3))
norm = colors.Normalize(vmin=-1, vmax=1.)
norm.autoscale(pixel_colors)
pixel_colors = norm(pixel_colors).tolist()

axis.scatter(h.flatten(), s.flatten(), v.flatten(), facecolors=pixel_colors,marker=".")
axis.set_xlabel("Hue")
axis.set_ylabel("Saturation")
axis.set_zlabel("Value")
plt.show()

lower_red = np.array([10, 100, 0])
upper_red = np.array([90, 250,255])

mask = cv2.inRange(hsv, lower_red, upper_red)

res = cv2.bitwise_and(frame, frame, mask=mask)

cv2.imshow("frame", frame)
cv2.imshow("mask", mask)
cv2.imshow("res", res)
cv2.waitKey(0)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-77-90153e21cb17> in <module>
#       5 frame = cv2.imread("dujuan_1.jpg")
#       6 # BGR空间转换到HSV颜色空间
# ----> 7 hsv = cv2.cvtColor(frame, cv2.COLOR_BGR2HSV)
#       8 # 分割通道
#       9 h, s, v = cv2.split(hsv)
#
# error: OpenCV(4.5.1) C:\Users\appveyor\AppData\Local\Temp\1\pip-req-build-oduouqig\opencv\modules\imgproc\src\color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cv::cvtColor'

# %% [markdown]
# fig.add_subplot(111)就是构成1x1子图，第一个子图，234就是2x3个图中第4的子图
# projection是投影的意思
# 组合起来就可以在111图中画3D图

# %% [markdown]
# HSV在用于指定颜色分割时，有比较大的作用。
#
# H和S分量代表了色彩信息。
#
# 分割应用：
#
#       用H和S分量来表示颜色距离，颜色距离指代表两种颜色之间的数值差异。
#      Androutsos等人通过实验对HSV颜色空间进行了大致划分，亮度大于75%并且饱和度大于20%为亮彩色区域，亮度小于25%为黑色区域，亮度大于75%并且饱和度小于20%为白色区域，其他为彩色区域。
#
#    对于不同的彩色区域，混合H与S变量，划定阈值，即可进行简单的分割。

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
img0=cv2.imread('dujuan_1.png')
print(img0.shape)
# b,g,r=cv2.split(img0)
# img0=cv2.merge([r,g,b])
#plt.imshow(img0)
cv2.imshow('1',img0)
cv2.waitKey()
cv2.destroyAllWindows()
img1=cv2.cvtColor(img0,cv2.COLOR_BGR2HSV)
lower_red=np.array([0,100,47])
upper_red=np.array([0,100,47])
mask=cv2.inRange(img1,lower_red,upper_red)
res=cv2.bitwise_and(img0,img0,mask=mask)
b,g,r=cv2.split(res)
res=cv2.merge([r,g,b])
cv2.imshow('red',res)
cv2.waitKey()
cv2.destroyAllWindows()
# plt.imshow(img0)
# Out:
# (761, 741, 3)

# %% [markdown]
# 在用插件读取某一个红色点的像素值时，获得了HSL值。
# HSL是一种将RGB色彩模型中的点在圆柱坐标系中的表示法。baiHSL即色相（Hue）、饱和度（ Saturation）、亮度（ Lightness）。
#
# HSL的色相（H）是色彩的基本属性，就是颜色名称，如红色、黄色等。色相就是由原色、间色和复色来构成的。色相是色彩的首要特征，是区别各种不同色彩的最准确的标准。
#
# HSL的饱和度（S）是色彩的鲜艳程度，也称色彩的纯度。饱和度取决于该色中含色成分和消色成分（灰色）的比例。含色成分越大，饱和度越大；消色成分越大，饱和度越小。取0-100%的数值。
#
# HSL的明度（L）是颜色的明暗程度，主要是由光线强弱决定的一种视觉经验。色调相同的颜色，明暗可能不同。一般来说，光线越强，看上去越亮；光线越弱，看上去越暗。

# %% [markdown]
# 区别：HSB 和 HSV 是是一样的，只是叫法不同，HSL 则还有一些细微的区别

# %%
# img0=cv2.imread('dujuan_1.png')
# print(img0.shape)
# img1=cv2.cvtColor(img0,cv2.COLOR_BGR2HSV)
# h,s,v=cv2.split(img1)
# img1[:,:,max(v)]
